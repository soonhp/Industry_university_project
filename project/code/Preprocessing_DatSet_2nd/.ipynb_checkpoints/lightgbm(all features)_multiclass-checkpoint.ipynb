# %%
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV, RFE
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

s=time.time()


df_train = pd.read_excel('df_total_raw_train.xlsx', na_values=['-OVER','+OVER'])
df_train.interpolate(inplace=True)

df_test = pd.read_excel('df_total_raw_test.xlsx', na_values=['-OVER','+OVER'])
df_test.interpolate(inplace=True)

x_train = df_train.drop(['Heat_ON'],axis=1)
y_train = df_train['Heat_ON']

x_test = df_test.drop(['Heat_ON'],axis=1)
y_test = df_test['Heat_ON']

# lightgbm classifier 선택
lgbmclf = LGBMClassifier(random_state=0, n_estimators=200, learning_rate=0.05, objective='multiclass')
# REFCV로 Feature들을 반복적으로 제거해가면서 학습/평가 수행
evals = [(x_test, y_test)]
lgbmclf.fit(x_train, y_train, early_stopping_rounds=100, eval_metric="multi_logloss", eval_set=evals, verbose=True)
lgbmclf_accuracy_score=accuracy_score(y_test, lgbmclf.predict(x_test))
print('acc : {0:.4f}'.format(lgbmclf_accuracy_score))
print(time.time()-s)
# Out:
# C:\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\anaconda3\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.818906
# [2]	valid_0's multi_logloss: 0.722176
# [3]	valid_0's multi_logloss: 0.643657
# [4]	valid_0's multi_logloss: 0.577097
# [5]	valid_0's multi_logloss: 0.519623
# [6]	valid_0's multi_logloss: 0.46937
# [7]	valid_0's multi_logloss: 0.425058
# [8]	valid_0's multi_logloss: 0.385768
# [9]	valid_0's multi_logloss: 0.35075
# [10]	valid_0's multi_logloss: 0.319361
# [11]	valid_0's multi_logloss: 0.291178
# [12]	valid_0's multi_logloss: 0.26577
# [13]	valid_0's multi_logloss: 0.242831
# [14]	valid_0's multi_logloss: 0.222065
# [15]	valid_0's multi_logloss: 0.203245
# [16]	valid_0's multi_logloss: 0.186161
# [17]	valid_0's multi_logloss: 0.170618
# [18]	valid_0's multi_logloss: 0.156473
# [19]	valid_0's multi_logloss: 0.143582
# [20]	valid_0's multi_logloss: 0.131833
# [21]	valid_0's multi_logloss: 0.121105
# [22]	valid_0's multi_logloss: 0.111308
# [23]	valid_0's multi_logloss: 0.102354
# [24]	valid_0's multi_logloss: 0.0941682
# [25]	valid_0's multi_logloss: 0.086652
# [26]	valid_0's multi_logloss: 0.0797959
# [27]	valid_0's multi_logloss: 0.0735085
# [28]	valid_0's multi_logloss: 0.0677252
# [29]	valid_0's multi_logloss: 0.0624284
# [30]	valid_0's multi_logloss: 0.0575678
# [31]	valid_0's multi_logloss: 0.0531076
# [32]	valid_0's multi_logloss: 0.0489923
# [33]	valid_0's multi_logloss: 0.0452269
# [34]	valid_0's multi_logloss: 0.0417468
# [35]	valid_0's multi_logloss: 0.038571
# [36]	valid_0's multi_logloss: 0.0356386
# [37]	valid_0's multi_logloss: 0.0329346
# [38]	valid_0's multi_logloss: 0.0304623
# [39]	valid_0's multi_logloss: 0.0281745
# [40]	valid_0's multi_logloss: 0.0260864
# [41]	valid_0's multi_logloss: 0.0241466
# [42]	valid_0's multi_logloss: 0.0223669
# [43]	valid_0's multi_logloss: 0.0207269
# [44]	valid_0's multi_logloss: 0.019214
# [45]	valid_0's multi_logloss: 0.0178269
# [46]	valid_0's multi_logloss: 0.0165421
# [47]	valid_0's multi_logloss: 0.0153536
# [48]	valid_0's multi_logloss: 0.0142695
# [49]	valid_0's multi_logloss: 0.0132663
# [50]	valid_0's multi_logloss: 0.0123358
# [51]	valid_0's multi_logloss: 0.0114817
# [52]	valid_0's multi_logloss: 0.0106986
# [53]	valid_0's multi_logloss: 0.00996129
# [54]	valid_0's multi_logloss: 0.00930555
# [55]	valid_0's multi_logloss: 0.00869111
# [56]	valid_0's multi_logloss: 0.00812194
# [57]	valid_0's multi_logloss: 0.00760754
# [58]	valid_0's multi_logloss: 0.00712637
# [59]	valid_0's multi_logloss: 0.00668986
# [60]	valid_0's multi_logloss: 0.00628187
# [61]	valid_0's multi_logloss: 0.00590776
# [62]	valid_0's multi_logloss: 0.00555301
# [63]	valid_0's multi_logloss: 0.0052347
# [64]	valid_0's multi_logloss: 0.00492971
# [65]	valid_0's multi_logloss: 0.0046637
# [66]	valid_0's multi_logloss: 0.00440135
# [67]	valid_0's multi_logloss: 0.00416558
# [68]	valid_0's multi_logloss: 0.00394316
# [69]	valid_0's multi_logloss: 0.00374289
# [70]	valid_0's multi_logloss: 0.00355998
# [71]	valid_0's multi_logloss: 0.00339231
# [72]	valid_0's multi_logloss: 0.00322936
# [73]	valid_0's multi_logloss: 0.00308711
# [74]	valid_0's multi_logloss: 0.00295426
# [75]	valid_0's multi_logloss: 0.00283433
# [76]	valid_0's multi_logloss: 0.00271314
# [77]	valid_0's multi_logloss: 0.00260883
# [78]	valid_0's multi_logloss: 0.00250697
# [79]	valid_0's multi_logloss: 0.00240442
# [80]	valid_0's multi_logloss: 0.00230785
# [81]	valid_0's multi_logloss: 0.00222216
# [82]	valid_0's multi_logloss: 0.00214329
# [83]	valid_0's multi_logloss: 0.00207446
# [84]	valid_0's multi_logloss: 0.00201313
# [85]	valid_0's multi_logloss: 0.00195307
# [86]	valid_0's multi_logloss: 0.00189907
# [87]	valid_0's multi_logloss: 0.00184681
# [88]	valid_0's multi_logloss: 0.00179397
# [89]	valid_0's multi_logloss: 0.00174232
# [90]	valid_0's multi_logloss: 0.00169858
# [91]	valid_0's multi_logloss: 0.00166044
# [92]	valid_0's multi_logloss: 0.00162139
# [93]	valid_0's multi_logloss: 0.00158748
# [94]	valid_0's multi_logloss: 0.00155879
# [95]	valid_0's multi_logloss: 0.00153221
# [96]	valid_0's multi_logloss: 0.00150928
# [97]	valid_0's multi_logloss: 0.0014806
# [98]	valid_0's multi_logloss: 0.00145395
# [99]	valid_0's multi_logloss: 0.00142942
# [100]	valid_0's multi_logloss: 0.00141013
# [101]	valid_0's multi_logloss: 0.00138448
# [102]	valid_0's multi_logloss: 0.00136357
# [103]	valid_0's multi_logloss: 0.00134947
# [104]	valid_0's multi_logloss: 0.00133102
# [105]	valid_0's multi_logloss: 0.00131636
# [106]	valid_0's multi_logloss: 0.00130262
# [107]	valid_0's multi_logloss: 0.00128851
# [108]	valid_0's multi_logloss: 0.00127917
# [109]	valid_0's multi_logloss: 0.0012721
# [110]	valid_0's multi_logloss: 0.00126604
# [111]	valid_0's multi_logloss: 0.00125802
# [112]	valid_0's multi_logloss: 0.00124668
# [113]	valid_0's multi_logloss: 0.00124122
# [114]	valid_0's multi_logloss: 0.00123409
# [115]	valid_0's multi_logloss: 0.00122928
# [116]	valid_0's multi_logloss: 0.00122108
# [117]	valid_0's multi_logloss: 0.00121373
# [118]	valid_0's multi_logloss: 0.00120796
# [119]	valid_0's multi_logloss: 0.00120019
# [120]	valid_0's multi_logloss: 0.00118537
# [121]	valid_0's multi_logloss: 0.00118245
# [122]	valid_0's multi_logloss: 0.00118539
# [123]	valid_0's multi_logloss: 0.0011853
# [124]	valid_0's multi_logloss: 0.00118316
# [125]	valid_0's multi_logloss: 0.00118058
# [126]	valid_0's multi_logloss: 0.00117626
# [127]	valid_0's multi_logloss: 0.00117191
# [128]	valid_0's multi_logloss: 0.00116894
# [129]	valid_0's multi_logloss: 0.0011652
# [130]	valid_0's multi_logloss: 0.00116417
# [131]	valid_0's multi_logloss: 0.00116561
# [132]	valid_0's multi_logloss: 0.00116781
# [133]	valid_0's multi_logloss: 0.00117258
# [134]	valid_0's multi_logloss: 0.00117875
# [135]	valid_0's multi_logloss: 0.00118127
# [136]	valid_0's multi_logloss: 0.00118225
# [137]	valid_0's multi_logloss: 0.0011835
# [138]	valid_0's multi_logloss: 0.00118546
# [139]	valid_0's multi_logloss: 0.00118647
# [140]	valid_0's multi_logloss: 0.00119522
# [141]	valid_0's multi_logloss: 0.00119397
# [142]	valid_0's multi_logloss: 0.00119756
# [143]	valid_0's multi_logloss: 0.00120097
# [144]	valid_0's multi_logloss: 0.00120261
# [145]	valid_0's multi_logloss: 0.00120345
# [146]	valid_0's multi_logloss: 0.00120216
# [147]	valid_0's multi_logloss: 0.0012011
# [148]	valid_0's multi_logloss: 0.00121002
# [149]	valid_0's multi_logloss: 0.00121184
# [150]	valid_0's multi_logloss: 0.00121264
# [151]	valid_0's multi_logloss: 0.00121293
# [152]	valid_0's multi_logloss: 0.00121798
# [153]	valid_0's multi_logloss: 0.0012226
# [154]	valid_0's multi_logloss: 0.00122245
# [155]	valid_0's multi_logloss: 0.0012217
# [156]	valid_0's multi_logloss: 0.00122647
# [157]	valid_0's multi_logloss: 0.00122436
# [158]	valid_0's multi_logloss: 0.00122232
# [159]	valid_0's multi_logloss: 0.00122044
# [160]	valid_0's multi_logloss: 0.00121475
# [161]	valid_0's multi_logloss: 0.00121449
# [162]	valid_0's multi_logloss: 0.00121381
# [163]	valid_0's multi_logloss: 0.00121109
# [164]	valid_0's multi_logloss: 0.00120539
# [165]	valid_0's multi_logloss: 0.00120288
# [166]	valid_0's multi_logloss: 0.00120678
# [167]	valid_0's multi_logloss: 0.00121142
# [168]	valid_0's multi_logloss: 0.00121641
# [169]	valid_0's multi_logloss: 0.00121172
# [170]	valid_0's multi_logloss: 0.00120927
# [171]	valid_0's multi_logloss: 0.00121277
# [172]	valid_0's multi_logloss: 0.00121024
# [173]	valid_0's multi_logloss: 0.00121544
# [174]	valid_0's multi_logloss: 0.00121398
# [175]	valid_0's multi_logloss: 0.00121339
# [176]	valid_0's multi_logloss: 0.001209
# [177]	valid_0's multi_logloss: 0.00120575
# [178]	valid_0's multi_logloss: 0.00120438
# [179]	valid_0's multi_logloss: 0.00120459
# [180]	valid_0's multi_logloss: 0.00119926
# [181]	valid_0's multi_logloss: 0.00119978
# [182]	valid_0's multi_logloss: 0.00120309
# [183]	valid_0's multi_logloss: 0.0011967
# [184]	valid_0's multi_logloss: 0.00120069
# [185]	valid_0's multi_logloss: 0.00119964
# [186]	valid_0's multi_logloss: 0.0011982
# [187]	valid_0's multi_logloss: 0.00119701
# [188]	valid_0's multi_logloss: 0.00119366
# [189]	valid_0's multi_logloss: 0.00119496
# [190]	valid_0's multi_logloss: 0.00119577
# [191]	valid_0's multi_logloss: 0.00119571
# [192]	valid_0's multi_logloss: 0.00119427
# [193]	valid_0's multi_logloss: 0.0011947
# [194]	valid_0's multi_logloss: 0.00119232
# [195]	valid_0's multi_logloss: 0.00119264
# [196]	valid_0's multi_logloss: 0.00119156
# [197]	valid_0's multi_logloss: 0.00119115
# [198]	valid_0's multi_logloss: 0.0011889
# [199]	valid_0's multi_logloss: 0.00118589
# [200]	valid_0's multi_logloss: 0.00118439
# acc : 0.9996
# 79.63580083847046

# %%
from lightgbm import plot_importance
plot_importance(lgbmclf,max_num_features=10, importance_type='gain')
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
y_pred = lgbmclf.predict(x_test)
from sklearn.metrics import roc_auc_score, f1_score
from sklearn.metrics import plot_confusion_matrix, confusion_matrix

f1_score(y_test, y_pred, average='micro')
# Out:
# 0.9995610637748515
