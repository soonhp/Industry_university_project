# %%
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV, RFE
from sklearn.metrics import roc_auc_score, f1_score
from sklearn.metrics import accuracy_score
s=time.time()

df_train = pd.read_excel('df_total_raw_train.xlsx', na_values=['-OVER','+OVER'])
df_train.interpolate(inplace=True)

df_test = pd.read_excel('df_total_raw_test.xlsx', na_values=['-OVER','+OVER'])
df_test.interpolate(inplace=True)

x_train = df_train[['eva air out temp_MIN', 'inside temp_MIN','T3_cond in_MIN', 'eva air out temp_MAX', 'T2_comp out_MAX', 'T1_comp in_MAX', 'T3_cond in_MAX', 'T5_Exp in_MAX', 'T8_2-T7_MIN', 'T5_Exp in_MIN']]
y_train = df_train['Heat_ON']

x_test = df_test[['eva air out temp_MIN', 'inside temp_MIN','T3_cond in_MIN', 'eva air out temp_MAX', 'T2_comp out_MAX', 'T1_comp in_MAX', 'T3_cond in_MAX', 'T5_Exp in_MAX', 'T8_2-T7_MIN', 'T5_Exp in_MIN']]
y_test = df_test['Heat_ON']


# lightgbm classifier 선택
lgbmclf = LGBMClassifier(random_state=0, n_estimators=200, learning_rate=0.05, objective='multiclass')
# REFCV로 Feature들을 반복적으로 제거해가면서 학습/평가 수행
evals = [(x_test, y_test)]
lgbmclf.fit(x_train, y_train, early_stopping_rounds=100, eval_metric="multi_logloss", eval_set=evals, verbose=True)
lgbmclf_accuracy_score=accuracy_score(y_test, lgbmclf.predict(x_test))
print('acc : {0:.4f}'.format(lgbmclf_accuracy_score))
print(time.time()-s)
# Out:
# C:\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\anaconda3\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.819019
# [2]	valid_0's multi_logloss: 0.722396
# [3]	valid_0's multi_logloss: 0.643945
# [4]	valid_0's multi_logloss: 0.577471
# [5]	valid_0's multi_logloss: 0.520006
# [6]	valid_0's multi_logloss: 0.469784
# [7]	valid_0's multi_logloss: 0.425517
# [8]	valid_0's multi_logloss: 0.386247
# [9]	valid_0's multi_logloss: 0.35126
# [10]	valid_0's multi_logloss: 0.319928
# [11]	valid_0's multi_logloss: 0.291758
# [12]	valid_0's multi_logloss: 0.266369
# [13]	valid_0's multi_logloss: 0.243446
# [14]	valid_0's multi_logloss: 0.222717
# [15]	valid_0's multi_logloss: 0.203909
# [16]	valid_0's multi_logloss: 0.186817
# [17]	valid_0's multi_logloss: 0.171279
# [18]	valid_0's multi_logloss: 0.157159
# [19]	valid_0's multi_logloss: 0.144311
# [20]	valid_0's multi_logloss: 0.132587
# [21]	valid_0's multi_logloss: 0.121868
# [22]	valid_0's multi_logloss: 0.112084
# [23]	valid_0's multi_logloss: 0.103121
# [24]	valid_0's multi_logloss: 0.0949255
# [25]	valid_0's multi_logloss: 0.0874183
# [26]	valid_0's multi_logloss: 0.080541
# [27]	valid_0's multi_logloss: 0.074237
# [28]	valid_0's multi_logloss: 0.0684554
# [29]	valid_0's multi_logloss: 0.0631561
# [30]	valid_0's multi_logloss: 0.0582963
# [31]	valid_0's multi_logloss: 0.05384
# [32]	valid_0's multi_logloss: 0.0497436
# [33]	valid_0's multi_logloss: 0.0459855
# [34]	valid_0's multi_logloss: 0.0425314
# [35]	valid_0's multi_logloss: 0.0393666
# [36]	valid_0's multi_logloss: 0.0364422
# [37]	valid_0's multi_logloss: 0.0337465
# [38]	valid_0's multi_logloss: 0.0312703
# [39]	valid_0's multi_logloss: 0.0289866
# [40]	valid_0's multi_logloss: 0.0268701
# [41]	valid_0's multi_logloss: 0.0249393
# [42]	valid_0's multi_logloss: 0.0231537
# [43]	valid_0's multi_logloss: 0.0215193
# [44]	valid_0's multi_logloss: 0.0200198
# [45]	valid_0's multi_logloss: 0.0186435
# [46]	valid_0's multi_logloss: 0.0173682
# [47]	valid_0's multi_logloss: 0.0161999
# [48]	valid_0's multi_logloss: 0.0151252
# [49]	valid_0's multi_logloss: 0.0141351
# [50]	valid_0's multi_logloss: 0.0132213
# [51]	valid_0's multi_logloss: 0.0123778
# [52]	valid_0's multi_logloss: 0.0116014
# [53]	valid_0's multi_logloss: 0.0108848
# [54]	valid_0's multi_logloss: 0.0102214
# [55]	valid_0's multi_logloss: 0.00961004
# [56]	valid_0's multi_logloss: 0.0090457
# [57]	valid_0's multi_logloss: 0.00852063
# [58]	valid_0's multi_logloss: 0.0080316
# [59]	valid_0's multi_logloss: 0.00758578
# [60]	valid_0's multi_logloss: 0.00718033
# [61]	valid_0's multi_logloss: 0.00679191
# [62]	valid_0's multi_logloss: 0.00644191
# [63]	valid_0's multi_logloss: 0.00610779
# [64]	valid_0's multi_logloss: 0.0058004
# [65]	valid_0's multi_logloss: 0.0055115
# [66]	valid_0's multi_logloss: 0.00525073
# [67]	valid_0's multi_logloss: 0.00500778
# [68]	valid_0's multi_logloss: 0.00479478
# [69]	valid_0's multi_logloss: 0.00459171
# [70]	valid_0's multi_logloss: 0.00440084
# [71]	valid_0's multi_logloss: 0.00421927
# [72]	valid_0's multi_logloss: 0.00405419
# [73]	valid_0's multi_logloss: 0.00389409
# [74]	valid_0's multi_logloss: 0.00373827
# [75]	valid_0's multi_logloss: 0.00360194
# [76]	valid_0's multi_logloss: 0.00348047
# [77]	valid_0's multi_logloss: 0.00335956
# [78]	valid_0's multi_logloss: 0.00324904
# [79]	valid_0's multi_logloss: 0.00314393
# [80]	valid_0's multi_logloss: 0.00304862
# [81]	valid_0's multi_logloss: 0.00296064
# [82]	valid_0's multi_logloss: 0.00287363
# [83]	valid_0's multi_logloss: 0.00279866
# [84]	valid_0's multi_logloss: 0.00272604
# [85]	valid_0's multi_logloss: 0.00266105
# [86]	valid_0's multi_logloss: 0.00259273
# [87]	valid_0's multi_logloss: 0.00253256
# [88]	valid_0's multi_logloss: 0.00248171
# [89]	valid_0's multi_logloss: 0.00243284
# [90]	valid_0's multi_logloss: 0.00237931
# [91]	valid_0's multi_logloss: 0.00234573
# [92]	valid_0's multi_logloss: 0.00230658
# [93]	valid_0's multi_logloss: 0.00227093
# [94]	valid_0's multi_logloss: 0.0022452
# [95]	valid_0's multi_logloss: 0.00221436
# [96]	valid_0's multi_logloss: 0.00219674
# [97]	valid_0's multi_logloss: 0.00218119
# [98]	valid_0's multi_logloss: 0.00215579
# [99]	valid_0's multi_logloss: 0.00214634
# [100]	valid_0's multi_logloss: 0.00211741
# [101]	valid_0's multi_logloss: 0.00209076
# [102]	valid_0's multi_logloss: 0.0020699
# [103]	valid_0's multi_logloss: 0.00204795
# [104]	valid_0's multi_logloss: 0.00203352
# [105]	valid_0's multi_logloss: 0.00202585
# [106]	valid_0's multi_logloss: 0.00201062
# [107]	valid_0's multi_logloss: 0.00199253
# [108]	valid_0's multi_logloss: 0.00198137
# [109]	valid_0's multi_logloss: 0.0019677
# [110]	valid_0's multi_logloss: 0.00195159
# [111]	valid_0's multi_logloss: 0.00193424
# [112]	valid_0's multi_logloss: 0.00192629
# [113]	valid_0's multi_logloss: 0.00191549
# [114]	valid_0's multi_logloss: 0.00190892
# [115]	valid_0's multi_logloss: 0.00190434
# [116]	valid_0's multi_logloss: 0.00189617
# [117]	valid_0's multi_logloss: 0.00189149
# [118]	valid_0's multi_logloss: 0.00188421
# [119]	valid_0's multi_logloss: 0.0018838
# [120]	valid_0's multi_logloss: 0.00188273
# [121]	valid_0's multi_logloss: 0.00187691
# [122]	valid_0's multi_logloss: 0.00188075
# [123]	valid_0's multi_logloss: 0.00188003
# [124]	valid_0's multi_logloss: 0.00188092
# [125]	valid_0's multi_logloss: 0.00187552
# [126]	valid_0's multi_logloss: 0.00188095
# [127]	valid_0's multi_logloss: 0.00187828
# [128]	valid_0's multi_logloss: 0.00187951
# [129]	valid_0's multi_logloss: 0.00188282
# [130]	valid_0's multi_logloss: 0.00189103
# [131]	valid_0's multi_logloss: 0.00189885
# [132]	valid_0's multi_logloss: 0.00190818
# [133]	valid_0's multi_logloss: 0.00191401
# [134]	valid_0's multi_logloss: 0.00192434
# [135]	valid_0's multi_logloss: 0.00193976
# [136]	valid_0's multi_logloss: 0.00195871
# [137]	valid_0's multi_logloss: 0.00197287
# [138]	valid_0's multi_logloss: 0.00199243
# [139]	valid_0's multi_logloss: 0.00199626
# [140]	valid_0's multi_logloss: 0.00200241
# [141]	valid_0's multi_logloss: 0.00201736
# [142]	valid_0's multi_logloss: 0.00203207
# [143]	valid_0's multi_logloss: 0.00203985
# [144]	valid_0's multi_logloss: 0.00205516
# [145]	valid_0's multi_logloss: 0.00207038
# [146]	valid_0's multi_logloss: 0.00208316
# [147]	valid_0's multi_logloss: 0.00209692
# [148]	valid_0's multi_logloss: 0.00211189
# [149]	valid_0's multi_logloss: 0.00211522
# [150]	valid_0's multi_logloss: 0.00212331
# [151]	valid_0's multi_logloss: 0.00213652
# [152]	valid_0's multi_logloss: 0.00214575
# [153]	valid_0's multi_logloss: 0.00215212
# [154]	valid_0's multi_logloss: 0.00216023
# [155]	valid_0's multi_logloss: 0.00216089
# [156]	valid_0's multi_logloss: 0.0021662
# [157]	valid_0's multi_logloss: 0.00217174
# [158]	valid_0's multi_logloss: 0.00218305
# [159]	valid_0's multi_logloss: 0.00219111
# [160]	valid_0's multi_logloss: 0.00219347
# [161]	valid_0's multi_logloss: 0.00220059
# [162]	valid_0's multi_logloss: 0.00220682
# [163]	valid_0's multi_logloss: 0.00221807
# [164]	valid_0's multi_logloss: 0.00222236
# [165]	valid_0's multi_logloss: 0.0022269
# [166]	valid_0's multi_logloss: 0.00222782
# [167]	valid_0's multi_logloss: 0.00224342
# [168]	valid_0's multi_logloss: 0.00224759
# [169]	valid_0's multi_logloss: 0.00225364
# [170]	valid_0's multi_logloss: 0.00225153
# [171]	valid_0's multi_logloss: 0.00225724
# [172]	valid_0's multi_logloss: 0.00226316
# [173]	valid_0's multi_logloss: 0.00227005
# [174]	valid_0's multi_logloss: 0.00228199
# [175]	valid_0's multi_logloss: 0.00228705
# [176]	valid_0's multi_logloss: 0.00230369
# [177]	valid_0's multi_logloss: 0.00231224
# [178]	valid_0's multi_logloss: 0.00231985
# [179]	valid_0's multi_logloss: 0.00231716
# [180]	valid_0's multi_logloss: 0.00232231
# [181]	valid_0's multi_logloss: 0.00232827
# [182]	valid_0's multi_logloss: 0.00232894
# [183]	valid_0's multi_logloss: 0.00233252
# [184]	valid_0's multi_logloss: 0.00233626
# [185]	valid_0's multi_logloss: 0.00233747
# [186]	valid_0's multi_logloss: 0.0023414
# [187]	valid_0's multi_logloss: 0.00234141
# [188]	valid_0's multi_logloss: 0.00235269
# [189]	valid_0's multi_logloss: 0.00236503
# [190]	valid_0's multi_logloss: 0.0023698
# [191]	valid_0's multi_logloss: 0.00238327
# [192]	valid_0's multi_logloss: 0.00240135
# [193]	valid_0's multi_logloss: 0.00240437
# [194]	valid_0's multi_logloss: 0.00240813
# [195]	valid_0's multi_logloss: 0.0024142
# [196]	valid_0's multi_logloss: 0.00241265
# [197]	valid_0's multi_logloss: 0.00240699
# [198]	valid_0's multi_logloss: 0.00240777
# [199]	valid_0's multi_logloss: 0.00241019
# [200]	valid_0's multi_logloss: 0.00241213
# acc : 0.9996
# 71.29255771636963

# %%
y_pred = lgbmclf.predict(x_test)
from sklearn.metrics import roc_auc_score, f1_score
from sklearn.metrics import plot_confusion_matrix, confusion_matrix

f1_score(y_test, y_pred, average='micro')
# Out:
# 0.9995868835528015
