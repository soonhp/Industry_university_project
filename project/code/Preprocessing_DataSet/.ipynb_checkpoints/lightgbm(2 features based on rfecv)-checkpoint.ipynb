# %%
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV, RFE
from sklearn.metrics import roc_auc_score

s=time.time()

df_train = pd.read_excel('df_total_train.xlsx', na_values=['-OVER','+OVER'])
df_train.interpolate(inplace=True)

df_test = pd.read_excel('df_total_test.xlsx', na_values=['-OVER','+OVER'])
df_test.interpolate(inplace=True)

x_train = df_train[['T2_comp out_MIN','inside temp_MIN']]
y_train = df_train['Heat_ON']

x_test = df_test[['T2_comp out_MIN','inside temp_MIN']]
y_test = df_test['Heat_ON']

# lightgbm classifier 선택
lgbmclf = LGBMClassifier(random_state=0, n_estimators=200, learning_rate=0.05)
# REFCV로 Feature들을 반복적으로 제거해가면서 학습/평가 수행
evals = [(x_test, y_test)]
lgbmclf.fit(x_train, y_train, early_stopping_rounds=100, eval_metric="auc", eval_set=evals, verbose=True)
lgbmclf_roc_score=roc_auc_score(y_test, lgbmclf.predict_proba(x_test)[:,1],average='macro')
print('roc auc : {0:.4f}'.format(lgbmclf_roc_score))
print(time.time()-s)
# Out:
# C:\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\anaconda3\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's auc: 0.998404	valid_0's binary_logloss: 0.633988
# [2]	valid_0's auc: 0.998406	valid_0's binary_logloss: 0.590891
# [3]	valid_0's auc: 0.998406	valid_0's binary_logloss: 0.551853
# [4]	valid_0's auc: 0.998404	valid_0's binary_logloss: 0.516321
# [5]	valid_0's auc: 0.998394	valid_0's binary_logloss: 0.483847
# [6]	valid_0's auc: 0.998395	valid_0's binary_logloss: 0.454063
# [7]	valid_0's auc: 0.998394	valid_0's binary_logloss: 0.426664
# [8]	valid_0's auc: 0.998398	valid_0's binary_logloss: 0.401386
# [9]	valid_0's auc: 0.998416	valid_0's binary_logloss: 0.378005
# [10]	valid_0's auc: 0.998414	valid_0's binary_logloss: 0.356349
# [11]	valid_0's auc: 0.998415	valid_0's binary_logloss: 0.33623
# [12]	valid_0's auc: 0.998476	valid_0's binary_logloss: 0.317556
# [13]	valid_0's auc: 0.998477	valid_0's binary_logloss: 0.300126
# [14]	valid_0's auc: 0.998476	valid_0's binary_logloss: 0.283896
# [15]	valid_0's auc: 0.998477	valid_0's binary_logloss: 0.268712
# [16]	valid_0's auc: 0.998475	valid_0's binary_logloss: 0.254541
# [17]	valid_0's auc: 0.998459	valid_0's binary_logloss: 0.241253
# [18]	valid_0's auc: 0.998457	valid_0's binary_logloss: 0.228832
# [19]	valid_0's auc: 0.998458	valid_0's binary_logloss: 0.217157
# [20]	valid_0's auc: 0.998463	valid_0's binary_logloss: 0.206221
# [21]	valid_0's auc: 0.99847	valid_0's binary_logloss: 0.195936
# [22]	valid_0's auc: 0.99847	valid_0's binary_logloss: 0.186288
# [23]	valid_0's auc: 0.998471	valid_0's binary_logloss: 0.177182
# [24]	valid_0's auc: 0.998469	valid_0's binary_logloss: 0.16863
# [25]	valid_0's auc: 0.99847	valid_0's binary_logloss: 0.160568
# [26]	valid_0's auc: 0.998471	valid_0's binary_logloss: 0.152975
# [27]	valid_0's auc: 0.998471	valid_0's binary_logloss: 0.145817
# [28]	valid_0's auc: 0.998471	valid_0's binary_logloss: 0.139073
# [29]	valid_0's auc: 0.998471	valid_0's binary_logloss: 0.132708
# [30]	valid_0's auc: 0.998739	valid_0's binary_logloss: 0.126701
# [31]	valid_0's auc: 0.998991	valid_0's binary_logloss: 0.121031
# [32]	valid_0's auc: 0.998987	valid_0's binary_logloss: 0.115679
# [33]	valid_0's auc: 0.99899	valid_0's binary_logloss: 0.11062
# [34]	valid_0's auc: 0.998752	valid_0's binary_logloss: 0.105852
# [35]	valid_0's auc: 0.998757	valid_0's binary_logloss: 0.101334
# [36]	valid_0's auc: 0.998761	valid_0's binary_logloss: 0.0970625
# [37]	valid_0's auc: 0.998765	valid_0's binary_logloss: 0.0930204
# [38]	valid_0's auc: 0.998772	valid_0's binary_logloss: 0.0892039
# [39]	valid_0's auc: 0.998773	valid_0's binary_logloss: 0.0855889
# [40]	valid_0's auc: 0.998776	valid_0's binary_logloss: 0.0821612
# [41]	valid_0's auc: 0.998776	valid_0's binary_logloss: 0.0789182
# [42]	valid_0's auc: 0.998824	valid_0's binary_logloss: 0.0758523
# [43]	valid_0's auc: 0.998825	valid_0's binary_logloss: 0.072949
# [44]	valid_0's auc: 0.998827	valid_0's binary_logloss: 0.0701994
# [45]	valid_0's auc: 0.998832	valid_0's binary_logloss: 0.067598
# [46]	valid_0's auc: 0.998839	valid_0's binary_logloss: 0.065109
# [47]	valid_0's auc: 0.998842	valid_0's binary_logloss: 0.06275
# [48]	valid_0's auc: 0.998844	valid_0's binary_logloss: 0.0605211
# [49]	valid_0's auc: 0.999045	valid_0's binary_logloss: 0.0584004
# [50]	valid_0's auc: 0.999051	valid_0's binary_logloss: 0.0563982
# [51]	valid_0's auc: 0.999085	valid_0's binary_logloss: 0.0545006
# [52]	valid_0's auc: 0.9991	valid_0's binary_logloss: 0.0527031
# [53]	valid_0's auc: 0.999106	valid_0's binary_logloss: 0.050979
# [54]	valid_0's auc: 0.999108	valid_0's binary_logloss: 0.0493037
# [55]	valid_0's auc: 0.999114	valid_0's binary_logloss: 0.0477211
# [56]	valid_0's auc: 0.999113	valid_0's binary_logloss: 0.0462491
# [57]	valid_0's auc: 0.999122	valid_0's binary_logloss: 0.0448637
# [58]	valid_0's auc: 0.999126	valid_0's binary_logloss: 0.0435378
# [59]	valid_0's auc: 0.999401	valid_0's binary_logloss: 0.0422631
# [60]	valid_0's auc: 0.999405	valid_0's binary_logloss: 0.0410592
# [61]	valid_0's auc: 0.999406	valid_0's binary_logloss: 0.0399264
# [62]	valid_0's auc: 0.999415	valid_0's binary_logloss: 0.0388336
# [63]	valid_0's auc: 0.999409	valid_0's binary_logloss: 0.0378003
# [64]	valid_0's auc: 0.999432	valid_0's binary_logloss: 0.0368232
# [65]	valid_0's auc: 0.999428	valid_0's binary_logloss: 0.0358722
# [66]	valid_0's auc: 0.999426	valid_0's binary_logloss: 0.0349782
# [67]	valid_0's auc: 0.999444	valid_0's binary_logloss: 0.0341302
# [68]	valid_0's auc: 0.999442	valid_0's binary_logloss: 0.0333258
# [69]	valid_0's auc: 0.999444	valid_0's binary_logloss: 0.0325619
# [70]	valid_0's auc: 0.999454	valid_0's binary_logloss: 0.0318428
# [71]	valid_0's auc: 0.999505	valid_0's binary_logloss: 0.0311522
# [72]	valid_0's auc: 0.999507	valid_0's binary_logloss: 0.0304876
# [73]	valid_0's auc: 0.999536	valid_0's binary_logloss: 0.0298462
# [74]	valid_0's auc: 0.999537	valid_0's binary_logloss: 0.0292514
# [75]	valid_0's auc: 0.999539	valid_0's binary_logloss: 0.0286711
# [76]	valid_0's auc: 0.999539	valid_0's binary_logloss: 0.0281351
# [77]	valid_0's auc: 0.999544	valid_0's binary_logloss: 0.0276209
# [78]	valid_0's auc: 0.999549	valid_0's binary_logloss: 0.027145
# [79]	valid_0's auc: 0.999553	valid_0's binary_logloss: 0.0266772
# [80]	valid_0's auc: 0.999557	valid_0's binary_logloss: 0.0262374
# [81]	valid_0's auc: 0.999562	valid_0's binary_logloss: 0.0258123
# [82]	valid_0's auc: 0.999564	valid_0's binary_logloss: 0.0254097
# [83]	valid_0's auc: 0.999574	valid_0's binary_logloss: 0.0250313
# [84]	valid_0's auc: 0.999574	valid_0's binary_logloss: 0.0246701
# [85]	valid_0's auc: 0.999575	valid_0's binary_logloss: 0.0243235
# [86]	valid_0's auc: 0.999579	valid_0's binary_logloss: 0.0239952
# [87]	valid_0's auc: 0.999579	valid_0's binary_logloss: 0.0236844
# [88]	valid_0's auc: 0.999579	valid_0's binary_logloss: 0.0233902
# [89]	valid_0's auc: 0.99958	valid_0's binary_logloss: 0.0231121
# [90]	valid_0's auc: 0.999584	valid_0's binary_logloss: 0.0228379
# [91]	valid_0's auc: 0.999608	valid_0's binary_logloss: 0.0225807
# [92]	valid_0's auc: 0.999614	valid_0's binary_logloss: 0.0223286
# [93]	valid_0's auc: 0.999619	valid_0's binary_logloss: 0.0220948
# [94]	valid_0's auc: 0.999621	valid_0's binary_logloss: 0.0218716
# [95]	valid_0's auc: 0.99962	valid_0's binary_logloss: 0.021665
# [96]	valid_0's auc: 0.999625	valid_0's binary_logloss: 0.0214687
# [97]	valid_0's auc: 0.999626	valid_0's binary_logloss: 0.0212826
# [98]	valid_0's auc: 0.999607	valid_0's binary_logloss: 0.0210894
# [99]	valid_0's auc: 0.99965	valid_0's binary_logloss: 0.0209091
# [100]	valid_0's auc: 0.999651	valid_0's binary_logloss: 0.0207348
# [101]	valid_0's auc: 0.999652	valid_0's binary_logloss: 0.0205712
# [102]	valid_0's auc: 0.999647	valid_0's binary_logloss: 0.0204158
# [103]	valid_0's auc: 0.999649	valid_0's binary_logloss: 0.020273
# [104]	valid_0's auc: 0.999648	valid_0's binary_logloss: 0.0201361
# [105]	valid_0's auc: 0.999656	valid_0's binary_logloss: 0.0200076
# [106]	valid_0's auc: 0.999656	valid_0's binary_logloss: 0.0198849
# [107]	valid_0's auc: 0.999656	valid_0's binary_logloss: 0.0197685
# [108]	valid_0's auc: 0.999655	valid_0's binary_logloss: 0.0196527
# [109]	valid_0's auc: 0.999655	valid_0's binary_logloss: 0.0195535
# [110]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0194451
# [111]	valid_0's auc: 0.999661	valid_0's binary_logloss: 0.0193392
# [112]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.0192437
# [113]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0191515
# [114]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0190729
# [115]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0189942
# [116]	valid_0's auc: 0.999665	valid_0's binary_logloss: 0.0189103
# [117]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0188304
# [118]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0187647
# [119]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0186962
# [120]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0186383
# [121]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0185782
# [122]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0185227
# [123]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0184685
# [124]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.018418
# [125]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.018375
# [126]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.0183345
# [127]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.0182896
# [128]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.0182494
# [129]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0182095
# [130]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.0181724
# [131]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.018133
# [132]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0181086
# [133]	valid_0's auc: 0.999665	valid_0's binary_logloss: 0.0180712
# [134]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0180484
# [135]	valid_0's auc: 0.999661	valid_0's binary_logloss: 0.0180288
# [136]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0179921
# [137]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0179678
# [138]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0179455
# [139]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0179248
# [140]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0179059
# [141]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.0178829
# [142]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0178608
# [143]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0178311
# [144]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.0178216
# [145]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.0178017
# [146]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.017784
# [147]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0177592
# [148]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0177411
# [149]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0177256
# [150]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0177026
# [151]	valid_0's auc: 0.999666	valid_0's binary_logloss: 0.0176877
# [152]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.0176835
# [153]	valid_0's auc: 0.999663	valid_0's binary_logloss: 0.0176631
# [154]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.017652
# [155]	valid_0's auc: 0.999664	valid_0's binary_logloss: 0.0176402
# [156]	valid_0's auc: 0.999662	valid_0's binary_logloss: 0.01764
# [157]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0176312
# [158]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.017629
# [159]	valid_0's auc: 0.999659	valid_0's binary_logloss: 0.0176204
# [160]	valid_0's auc: 0.999659	valid_0's binary_logloss: 0.017611
# [161]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0175978
# [162]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0175907
# [163]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.017583
# [164]	valid_0's auc: 0.999661	valid_0's binary_logloss: 0.0175697
# [165]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0175633
# [166]	valid_0's auc: 0.999661	valid_0's binary_logloss: 0.0175559
# [167]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0175479
# [168]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.017538
# [169]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0175347
# [170]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0175238
# [171]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0175228
# [172]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0175163
# [173]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0175111
# [174]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0175101
# [175]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0175028
# [176]	valid_0's auc: 0.999659	valid_0's binary_logloss: 0.0175003
# [177]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0174914
# [178]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0174891
# [179]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0174885
# [180]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0174886
# [181]	valid_0's auc: 0.99966	valid_0's binary_logloss: 0.0174904
# [182]	valid_0's auc: 0.999659	valid_0's binary_logloss: 0.0174919
# [183]	valid_0's auc: 0.999659	valid_0's binary_logloss: 0.0174981
# [184]	valid_0's auc: 0.999658	valid_0's binary_logloss: 0.0174978
# [185]	valid_0's auc: 0.999657	valid_0's binary_logloss: 0.0175037
# [186]	valid_0's auc: 0.999656	valid_0's binary_logloss: 0.0175035
# [187]	valid_0's auc: 0.999655	valid_0's binary_logloss: 0.0175072
# [188]	valid_0's auc: 0.999655	valid_0's binary_logloss: 0.0175074
# [189]	valid_0's auc: 0.999656	valid_0's binary_logloss: 0.0175071
# [190]	valid_0's auc: 0.999656	valid_0's binary_logloss: 0.0175089
# [191]	valid_0's auc: 0.999656	valid_0's binary_logloss: 0.0175092
# [192]	valid_0's auc: 0.999655	valid_0's binary_logloss: 0.0175142
# [193]	valid_0's auc: 0.999656	valid_0's binary_logloss: 0.0175146
# [194]	valid_0's auc: 0.999657	valid_0's binary_logloss: 0.0175119
# [195]	valid_0's auc: 0.999656	valid_0's binary_logloss: 0.0175185
# [196]	valid_0's auc: 0.999655	valid_0's binary_logloss: 0.0175254
# [197]	valid_0's auc: 0.999657	valid_0's binary_logloss: 0.0175134
# [198]	valid_0's auc: 0.999653	valid_0's binary_logloss: 0.0175139
# [199]	valid_0's auc: 0.999653	valid_0's binary_logloss: 0.0175148
# [200]	valid_0's auc: 0.999653	valid_0's binary_logloss: 0.017522
# roc auc : 0.9997
# 60.491283893585205

# %%
from lightgbm import plot_importance
plot_importance(lgbmclf,max_num_features=20, importance_type='gain')
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
y_pred = lgbmclf.predict(x_test)
from sklearn.metrics import roc_auc_score, f1_score
f1_score(y_test, y_pred, pos_label='On')
# Out:
# 0.9958787242420265
