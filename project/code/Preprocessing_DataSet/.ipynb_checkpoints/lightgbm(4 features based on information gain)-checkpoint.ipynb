# %%
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV, RFE
from sklearn.metrics import roc_auc_score, f1_score

s=time.time()

df_train = pd.read_excel('df_total_train.xlsx', na_values=['-OVER','+OVER'])
df_train.interpolate(inplace=True)

df_test = pd.read_excel('df_total_test.xlsx', na_values=['-OVER','+OVER'])
df_test.interpolate(inplace=True)

x_train = df_train[['T7_evap in_MAX','eva air out temp_MAX','eva air out temp_MIN','inside temp_MIN']]
y_train = df_train['Heat_ON']

x_test = df_test[['T7_evap in_MAX','eva air out temp_MAX','eva air out temp_MIN','inside temp_MIN']]
y_test = df_test['Heat_ON']

# lightgbm classifier 선택
lgbmclf = LGBMClassifier(random_state=0, n_estimators=200, learning_rate=0.05)
# REFCV로 Feature들을 반복적으로 제거해가면서 학습/평가 수행
evals = [(x_test, y_test)]
lgbmclf.fit(x_train, y_train, early_stopping_rounds=100, eval_metric="auc", eval_set=evals, verbose=True)
lgbmclf_roc_score=roc_auc_score(y_test, lgbmclf.predict_proba(x_test)[:,1],average='macro')
print('roc auc : {0:.4f}'.format(lgbmclf_roc_score))
print(time.time()-s)
# Out:
# C:\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\anaconda3\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's auc: 0.999675	valid_0's binary_logloss: 0.633303
# [2]	valid_0's auc: 0.999751	valid_0's binary_logloss: 0.589571
# [3]	valid_0's auc: 0.999751	valid_0's binary_logloss: 0.549956
# [4]	valid_0's auc: 0.999751	valid_0's binary_logloss: 0.513879
# [5]	valid_0's auc: 0.999751	valid_0's binary_logloss: 0.480907
# [6]	valid_0's auc: 0.999805	valid_0's binary_logloss: 0.450647
# [7]	valid_0's auc: 0.999801	valid_0's binary_logloss: 0.422807
# [8]	valid_0's auc: 0.999806	valid_0's binary_logloss: 0.397107
# [9]	valid_0's auc: 0.999807	valid_0's binary_logloss: 0.37334
# [10]	valid_0's auc: 0.999815	valid_0's binary_logloss: 0.351301
# [11]	valid_0's auc: 0.999951	valid_0's binary_logloss: 0.330808
# [12]	valid_0's auc: 0.999951	valid_0's binary_logloss: 0.311734
# [13]	valid_0's auc: 0.999951	valid_0's binary_logloss: 0.293961
# [14]	valid_0's auc: 0.999951	valid_0's binary_logloss: 0.277375
# [15]	valid_0's auc: 0.999951	valid_0's binary_logloss: 0.261875
# [16]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.247374
# [17]	valid_0's auc: 0.999951	valid_0's binary_logloss: 0.23379
# [18]	valid_0's auc: 0.999951	valid_0's binary_logloss: 0.221063
# [19]	valid_0's auc: 0.999951	valid_0's binary_logloss: 0.209112
# [20]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.197893
# [21]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.187347
# [22]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.177435
# [23]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.168093
# [24]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.159288
# [25]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.151001
# [26]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.143183
# [27]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.135812
# [28]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.128858
# [29]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.122282
# [30]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.116074
# [31]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.110206
# [32]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.104654
# [33]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.0994077
# [34]	valid_0's auc: 0.999953	valid_0's binary_logloss: 0.0944389
# [35]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.0897288
# [36]	valid_0's auc: 0.999953	valid_0's binary_logloss: 0.0852801
# [37]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.0810718
# [38]	valid_0's auc: 0.999953	valid_0's binary_logloss: 0.0770894
# [39]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.073311
# [40]	valid_0's auc: 0.999952	valid_0's binary_logloss: 0.0697275
# [41]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0663393
# [42]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0631169
# [43]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0600647
# [44]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0571787
# [45]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0544408
# [46]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.051852
# [47]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0493816
# [48]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0470385
# [49]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0448181
# [50]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0427091
# [51]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.040709
# [52]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0388105
# [53]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0370082
# [54]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0352992
# [55]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0336792
# [56]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0321357
# [57]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0306745
# [58]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0292848
# [59]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0279619
# [60]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0267105
# [61]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0255121
# [62]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0243738
# [63]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0232973
# [64]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0222733
# [65]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0213054
# [66]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0203783
# [67]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0194972
# [68]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0186647
# [69]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0178708
# [70]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0170837
# [71]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0163431
# [72]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0156334
# [73]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0149609
# [74]	valid_0's auc: 0.999986	valid_0's binary_logloss: 0.0143244
# [75]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0137156
# [76]	valid_0's auc: 0.999987	valid_0's binary_logloss: 0.0131388
# [77]	valid_0's auc: 0.999988	valid_0's binary_logloss: 0.0125937
# [78]	valid_0's auc: 0.999988	valid_0's binary_logloss: 0.0120692
# [79]	valid_0's auc: 0.999988	valid_0's binary_logloss: 0.0115775
# [80]	valid_0's auc: 0.999989	valid_0's binary_logloss: 0.0111033
# [81]	valid_0's auc: 0.999989	valid_0's binary_logloss: 0.0106564
# [82]	valid_0's auc: 0.999989	valid_0's binary_logloss: 0.0102323
# [83]	valid_0's auc: 0.999989	valid_0's binary_logloss: 0.00982644
# [84]	valid_0's auc: 0.999989	valid_0's binary_logloss: 0.00944596
# [85]	valid_0's auc: 0.999989	valid_0's binary_logloss: 0.00908034
# [86]	valid_0's auc: 0.999989	valid_0's binary_logloss: 0.00872978
# [87]	valid_0's auc: 0.99999	valid_0's binary_logloss: 0.00839733
# [88]	valid_0's auc: 0.99999	valid_0's binary_logloss: 0.00808118
# [89]	valid_0's auc: 0.99999	valid_0's binary_logloss: 0.00778152
# [90]	valid_0's auc: 0.99999	valid_0's binary_logloss: 0.00749806
# [91]	valid_0's auc: 0.99999	valid_0's binary_logloss: 0.00722788
# [92]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00697153
# [93]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00673234
# [94]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00650132
# [95]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00628655
# [96]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00607592
# [97]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00587495
# [98]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00568715
# [99]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00551115
# [100]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00534768
# [101]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00519723
# [102]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00505209
# [103]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00491036
# [104]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00477653
# [105]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00464899
# [106]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00451877
# [107]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00439459
# [108]	valid_0's auc: 0.999991	valid_0's binary_logloss: 0.00427725
# [109]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00416849
# [110]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00406272
# [111]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00396164
# [112]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00386728
# [113]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00377701
# [114]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00369095
# [115]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00359949
# [116]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00352174
# [117]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00344778
# [118]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00337806
# [119]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00331573
# [120]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00325209
# [121]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00319265
# [122]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00314024
# [123]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00308638
# [124]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00304029
# [125]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.0029935
# [126]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.0029496
# [127]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00290326
# [128]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00286409
# [129]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00283011
# [130]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00279551
# [131]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00275994
# [132]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00272999
# [133]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00269834
# [134]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00266647
# [135]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00264093
# [136]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00261727
# [137]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00259182
# [138]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00256364
# [139]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00253702
# [140]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00251566
# [141]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00249488
# [142]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00247821
# [143]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00246085
# [144]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00244516
# [145]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00242591
# [146]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00241349
# [147]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00240476
# [148]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00238254
# [149]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00236921
# [150]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00235646
# [151]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00234099
# [152]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00232624
# [153]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00231166
# [154]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00229962
# [155]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00229091
# [156]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00228364
# [157]	valid_0's auc: 0.999992	valid_0's binary_logloss: 0.00227975
# [158]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00227081
# [159]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00226257
# [160]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.0022588
# [161]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00225385
# [162]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00224322
# [163]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00223504
# [164]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222615
# [165]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00221559
# [166]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00220999
# [167]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.0022092
# [168]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00220687
# [169]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00220532
# [170]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00220124
# [171]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00219945
# [172]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00219574
# [173]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.0022011
# [174]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.002205
# [175]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00221027
# [176]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.0022177
# [177]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00221899
# [178]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00221642
# [179]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222116
# [180]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222903
# [181]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00223205
# [182]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00223598
# [183]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00223374
# [184]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00223198
# [185]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.0022253
# [186]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222359
# [187]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222114
# [188]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222296
# [189]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222463
# [190]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.002219
# [191]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00221979
# [192]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222199
# [193]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222679
# [194]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222988
# [195]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222834
# [196]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00223141
# [197]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00223088
# [198]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222959
# [199]	valid_0's auc: 0.999993	valid_0's binary_logloss: 0.00222364
# [200]	valid_0's auc: 0.999994	valid_0's binary_logloss: 0.00222528
# roc auc : 1.0000
# 59.17252469062805

# %%
y_pred = lgbmclf.predict(x_test)
from sklearn.metrics import roc_auc_score, f1_score
f1_score(y_test, y_pred, pos_label='On')

# %%
from sklearn.metrics import roc_auc_score, f1_score
f1_score(y_test, y_pred, pos_label='On')
# Out:
# 0.9994998288888304
